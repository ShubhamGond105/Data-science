# %%
### Pandas series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
###Data Frame

# %%
data= {
    'Name': ['Aryan', 'Shivam', 'Ashwani', 'Mohan'],
    'Age' : [23,24,26,24],
    'City' : ['Delhi','Gola','Lucknow','Jhumila'],
    'Salary' : [50000,30000,30000,40000]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age     City  Salary
# 0    Aryan   23    Delhi   50000
# 1   Shivam   24     Gola   30000
# 2  Ashwani   26  Lucknow   30000
# 3    Mohan   24  Jhumila   40000

# %%
df["Name"]
# Out:
# 0      Aryan
# 1     Shivam
# 2    Ashwani
# 3      Mohan
# Name: Name, dtype: object

# %%
df[["Name","Salary"]]
# Out:
#       Name  Salary
# 0    Aryan   50000
# 1   Shivam   30000
# 2  Ashwani   30000
# 3    Mohan   40000

# %%
df["Designation"]=["AI Trainer","Doctor","Sales","Eng."]

# %%
df
# Out:
#       Name  Age     City  Salary Designation
# 0    Aryan   23    Delhi   50000  AI Trainer
# 1   Shivam   24     Gola   30000      Doctor
# 2  Ashwani   26  Lucknow   30000       Sales
# 3    Mohan   24  Jhumila   40000        Eng.

# %%
df.drop("Designation",axis =1,inplace=True)

# %%
df
# Out:
#       Name  Age     City  Salary
# 0    Aryan   23    Delhi   50000
# 1   Shivam   24     Gola   30000
# 2  Ashwani   26  Lucknow   30000
# 3    Mohan   24  Jhumila   40000

# %%
df.drop("Age", axis=1)
# Out:
#       Name     City  Salary
# 0    Aryan    Delhi   50000
# 1   Shivam     Gola   30000
# 2  Ashwani  Lucknow   30000
# 3    Mohan  Jhumila   40000

# %%
df
# Out:
#       Name  Age     City  Salary
# 0    Aryan   23    Delhi   50000
# 1   Shivam   24     Gola   30000
# 2  Ashwani   26  Lucknow   30000
# 3    Mohan   24  Jhumila   40000

# %%
df.loc[0]
# Out:
# Name      Aryan
# Age          23
# City      Delhi
# Salary    50000
# Name: 0, dtype: object

# %%
df.loc[[2,3]]
# Out:
#       Name  Age     City  Salary
# 2  Ashwani   26  Lucknow   30000
# 3    Mohan   24  Jhumila   40000

# %%
df.loc[[2,3]][["City","Salary"]]
# Out:
#       City  Salary
# 2  Lucknow   30000
# 3  Jhumila   40000

# %%
d
# Out:
# {1: 10, 2: 20, 3: 30}

# %%
# only those age is above is 30

# %%
df[df["Age"]>25]
# Out:
#       Name  Age     City  Salary
# 2  Ashwani   26  Lucknow   30000

# %%
# only want people obove 20 and there city must be pairs

# %%
df[(df["Age"]>20) & (df["City"]=='Lucknow')]
# Out:
#       Name  Age     City  Salary
# 2  Ashwani   26  Lucknow   30000
